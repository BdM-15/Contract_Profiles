# %% [markdown]
# Top 10 Awards by SB and Socioeconomic Status.

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r'C:\PyProjects\OSBP Insights\data\raw\cleansed\data_source.csv')
# obsp_forecast_df = pd.read_csv(r'C:\PyProjects\OSBP Insights\references\forecast_listing\osbp_dashboard_forecast.csv')
# amc_forecast_df = pd.read_csv(r'C:\PyProjects\OSBP Insights\references\forecast_listing\amc_forecast_listing.csv')

# %%
# Filter acc_ri_awards_df to not inlcude any rows with a value of 'MODFICATION", "SATOC", AND "MATOC" in the 'Contract Action Type' column
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29329 entries, 0 to 29328
# Data columns (total 56 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Contract No                              29329 non-null  object
#  1   Order No                                 29329 non-null  object
#  2   Modification No                          29329 non-null  object
#  3   Award Date                               29329 non-null  object
#  4   Fiscal Year                              29329 non-null  int64
#  5   Command                                  29329 non-null  object
#  6   Sub Command                              29329 non-null  object
#  7   Organization                             29329 non-null  object
#  8   Office                                   29329 non-null  object
#  9   Office Id                                29329 non-null  object
#  10  Army Hierarchy                           29024 non-null  object
#  11  PEO/Command                              29024 non-null  object
#  12  PM/Directorate                           29024 non-null  object
#  13  VCE-PCF Project/Program Title            3950 non-null   object
#  14  Funding Office Id                        29329 non-null  object
#  15  Funding Office Name                      29329 non-null  object
#  16  Awardee                                  29328 non-null  object
#  17  Entity Unique Id                         29326 non-null  object
#  18  Small Business Eligible Actions          29329 non-null  int64
#  19  Small Business Eligible Dollars          29329 non-null  float64
#  20  Size Status                              29329 non-null  object
#  21  SB Dollars                               29329 non-null  float64
#  22  Small Business  %                        29329 non-null  object
#  23  SDB Concern Actions                      29329 non-null  int64
#  24  SDB Concern Dollars                      29329 non-null  float64
#  25  SDB Concern %                            29329 non-null  object
#  26  Service Disabled Veterans Actions        29329 non-null  int64
#  27  Service Disabled Veterans Dollars        29329 non-null  float64
#  28  SVC Disabled Veteran %                   29329 non-null  object
#  29  Women Owned Actions                      29329 non-null  int64
#  30  Women Owned Dollars                      29329 non-null  float64
#  31  Women Owned %                            29329 non-null  object
#  32  HUB Zone Actions                         29329 non-null  int64
#  33  HUB Zone Dollars                         29329 non-null  float64
#  34  HUB Zone %                               29329 non-null  object
#  35  OMB Level 1                              29329 non-null  object
#  36  OMB Level 2                              29329 non-null  object
#  37  PSC                                      29329 non-null  object
#  38  PSC Description                          29312 non-null  object
#  39  NAICS                                    29325 non-null  float64
#  40  NAICS Description                        29325 non-null  object
#  41  Congressional District - Vendor          28239 non-null  float64
#  42  Congressional District - POP             24150 non-null  float64
#  43  Subcontracting Plan Description          24933 non-null  object
#  44  National Interest Description            23149 non-null  object
#  45  SBIR/STTR Type                           53 non-null     object
#  46  Bundling                                 29185 non-null  object
#  47  Contract Expiration Flag                 29329 non-null  object
#  48  Expiration                               25298 non-null  object
#  49  Months Remaining                         25298 non-null  float64
#  50  Awarding PCO (CWS)                       28733 non-null  object
#  51  Type Set Aside Description               29329 non-null  object
#  52  Requirements Description                 29329 non-null  object
#  53  12C Reason for Modification Description  21632 non-null  object
#  54  Contract Action Type                     29329 non-null  object
#  55  Instrument Type                          29329 non-null  object
# dtypes: float64(10), int64(6), object(40)
# memory usage: 12.5+ MB

# %%
#Check for missing values
missing_values = df.isnull().sum()
print('Missing Values:\n', missing_values)
# Out:
# Missing Values:
#  Contract No                                    0
# Order No                                       0
# Modification No                                0
# Award Date                                     0
# Fiscal Year                                    0
# Command                                        0
# Sub Command                                    0
# Organization                                   0
# Office                                         0
# Office Id                                      0
# Army Hierarchy                               305
# PEO/Command                                  305
# PM/Directorate                               305
# VCE-PCF Project/Program Title              25379
# Funding Office Id                              0
# Funding Office Name                            0
# Awardee                                        1
# Entity Unique Id                               3
# Small Business Eligible Actions                0
# Small Business Eligible Dollars                0
# Size Status                                    0
# SB Dollars                                     0
# Small Business  %                              0
# SDB Concern Actions                            0
# SDB Concern Dollars                            0
# SDB Concern %                                  0
# Service Disabled Veterans Actions              0
# Service Disabled Veterans Dollars              0
# SVC Disabled Veteran %                         0
# Women Owned Actions                            0
# Women Owned Dollars                            0
# Women Owned %                                  0
# HUB Zone Actions                               0
# HUB Zone Dollars                               0
# HUB Zone %                                     0
# OMB Level 1                                    0
# OMB Level 2                                    0
# PSC                                            0
# PSC Description                               17
# NAICS                                          4
# NAICS Description                              4
# Congressional District - Vendor             1090
# Congressional District - POP                5179
# Subcontracting Plan Description             4396
# National Interest Description               6180
# SBIR/STTR Type                             29276
# Bundling                                     144
# Contract Expiration Flag                       0
# Expiration                                  4031
# Months Remaining                            4031
# Awarding PCO (CWS)                           596
# Type Set Aside Description                     0
# Requirements Description                       0
# 12C Reason for Modification Description     7697
# Contract Action Type                           0
# Instrument Type                                0
# dtype: int64

# %%
# Identify incorrect data types
print("Data Types:\n", df.dtypes)
# Out:
# Data Types:
#  Contract No                                 object
# Order No                                    object
# Modification No                             object
# Award Date                                  object
# Fiscal Year                                  int64
# Command                                     object
# Sub Command                                 object
# Organization                                object
# Office                                      object
# Office Id                                   object
# Army Hierarchy                              object
# PEO/Command                                 object
# PM/Directorate                              object
# VCE-PCF Project/Program Title               object
# Funding Office Id                           object
# Funding Office Name                         object
# Awardee                                     object
# Entity Unique Id                            object
# Small Business Eligible Actions              int64
# Small Business Eligible Dollars            float64
# Size Status                                 object
# SB Dollars                                 float64
# Small Business  %                           object
# SDB Concern Actions                          int64
# SDB Concern Dollars                        float64
# SDB Concern %                               object
# Service Disabled Veterans Actions            int64
# Service Disabled Veterans Dollars          float64
# SVC Disabled Veteran %                      object
# Women Owned Actions                          int64
# Women Owned Dollars                        float64
# Women Owned %                               object
# HUB Zone Actions                             int64
# HUB Zone Dollars                           float64
# HUB Zone %                                  object
# OMB Level 1                                 object
# OMB Level 2                                 object
# PSC                                         object
# PSC Description                             object
# NAICS                                      float64
# NAICS Description                           object
# Congressional District - Vendor            float64
# Congressional District - POP               float64
# Subcontracting Plan Description             object
# National Interest Description               object
# SBIR/STTR Type                              object
# Bundling                                    object
# Contract Expiration Flag                    object
# Expiration                                  object
# Months Remaining                           float64
# Awarding PCO (CWS)                          object
# Type Set Aside Description                  object
# Requirements Description                    object
# 12C Reason for Modification Description     object
# Contract Action Type                        object
# Instrument Type                             object
# dtype: object

# %%
# Convert dates to a consistent format
df['Award Date'] = pd.to_datetime(df['Award Date'], errors='coerce')
df['Expiration'] = pd.to_datetime(df['Expiration'], errors='coerce')
print("Award Date Data Type:", df['Award Date'].dtype)
print("Expiration Date Data Type:", df['Expiration'].dtype)
# Out:
# Award Date Data Type: datetime64[ns]
# Expiration Date Data Type: datetime64[ns]

# %%
# Convert 'Small Business Dollars' to numeric type if it is not already
df['SB Dollars'] = pd.to_numeric(df['SB Dollars'], errors='coerce')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29329 entries, 0 to 29328
# Data columns (total 56 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Contract No                              29329 non-null  object
#  1   Order No                                 29329 non-null  object
#  2   Modification No                          29329 non-null  object
#  3   Award Date                               29329 non-null  datetime64[ns]
#  4   Fiscal Year                              29329 non-null  int64
#  5   Command                                  29329 non-null  object
#  6   Sub Command                              29329 non-null  object
#  7   Organization                             29329 non-null  object
#  8   Office                                   29329 non-null  object
#  9   Office Id                                29329 non-null  object
#  10  Army Hierarchy                           29024 non-null  object
#  11  PEO/Command                              29024 non-null  object
#  12  PM/Directorate                           29024 non-null  object
#  13  VCE-PCF Project/Program Title            3950 non-null   object
#  14  Funding Office Id                        29329 non-null  object
#  15  Funding Office Name                      29329 non-null  object
#  16  Awardee                                  29328 non-null  object
#  17  Entity Unique Id                         29326 non-null  object
#  18  Small Business Eligible Actions          29329 non-null  int64
#  19  Small Business Eligible Dollars          29329 non-null  float64
#  20  Size Status                              29329 non-null  object
#  21  SB Dollars                               29329 non-null  float64
#  22  Small Business  %                        29329 non-null  object
#  23  SDB Concern Actions                      29329 non-null  int64
#  24  SDB Concern Dollars                      29329 non-null  float64
#  25  SDB Concern %                            29329 non-null  object
#  26  Service Disabled Veterans Actions        29329 non-null  int64
#  27  Service Disabled Veterans Dollars        29329 non-null  float64
#  28  SVC Disabled Veteran %                   29329 non-null  object
#  29  Women Owned Actions                      29329 non-null  int64
#  30  Women Owned Dollars                      29329 non-null  float64
#  31  Women Owned %                            29329 non-null  object
#  32  HUB Zone Actions                         29329 non-null  int64
#  33  HUB Zone Dollars                         29329 non-null  float64
#  34  HUB Zone %                               29329 non-null  object
#  35  OMB Level 1                              29329 non-null  object
#  36  OMB Level 2                              29329 non-null  object
#  37  PSC                                      29329 non-null  object
#  38  PSC Description                          29312 non-null  object
#  39  NAICS                                    29325 non-null  float64
#  40  NAICS Description                        29325 non-null  object
#  41  Congressional District - Vendor          28239 non-null  float64
#  42  Congressional District - POP             24150 non-null  float64
#  43  Subcontracting Plan Description          24933 non-null  object
#  44  National Interest Description            23149 non-null  object
#  45  SBIR/STTR Type                           53 non-null     object
#  46  Bundling                                 29185 non-null  object
#  47  Contract Expiration Flag                 29329 non-null  object
#  48  Expiration                               25298 non-null  object
#  49  Months Remaining                         25298 non-null  float64
#  50  Awarding PCO (CWS)                       28733 non-null  object
#  51  Type Set Aside Description               29329 non-null  object
#  52  Requirements Description                 29329 non-null  object
#  53  12C Reason for Modification Description  21632 non-null  object
#  54  Contract Action Type                     29329 non-null  object
#  55  Instrument Type                          29329 non-null  object
# dtypes: datetime64[ns](1), float64(10), int64(6), object(39)
# memory usage: 12.5+ MB

# %%
# Find outliers in numeric columns. An outlier would be a negative value in the 'Small Business Dollars' column
outliers = df[df['SB Dollars'] < 0]
print("Outliers:\n", outliers)
# Out:
# Outliers:
#            Contract No       Order No Modification No Award Date  Fiscal Year  \
# 25880      GS06F1159Z  W52P1J15F4007          P00004 2021-09-30         2021
# 25895   W52P1J18D4005  W52P1J18F6216          P00002 2023-09-07         2023
# 25896   W9098S20D0007  W9098S22F0043          P00002 2023-12-12         2024
# 25910   W52P1J16P4036           0000          P00004 2021-03-22         2021
# 25922      GS07F0254U  W52P1J19F0729          P00004 2023-05-16         2023
# ...               ...            ...             ...        ...          ...
# 29291   W52P1J15C0088           0000          P00005 2020-10-19         2021
# 29296   W52P1J17G0094           0001              40 2021-04-02         2021
# 29302   W52P1J18DA100  W52P1J20F0674          P00015 2023-02-07         2023
# 29314  GS00Q14OADS123  W52P1J20F0465          P00002 2020-12-02         2021
# 29315   W15P7T19D0013  W52P1J21F0153          P00003 2022-10-04         2023
#
#       Command Sub Command Organization                          Office  \
# 25880     ACC    ACC CTRS       ACC-RI  ACC-RI: ROCK ISLAND (INACTIVE)
# 25895     ACC    ACC CTRS       ACC-RI             ACC-RI: ROCK ISLAND
# 25896     ACC    ACC CTRS       ACC-RI             ACC-RI: ROCK ISLAND
# 25910     ACC    ACC CTRS       ACC-RI  ACC-RI: ROCK ISLAND (INACTIVE)
# 25922     ACC    ACC CTRS       ACC-RI             ACC-RI: ROCK ISLAND
# ...       ...         ...          ...                             ...
# 29291     ACC    ACC CTRS       ACC-RI  ACC-RI: ROCK ISLAND (INACTIVE)
# 29296     ACC    ACC CTRS       ACC-RI  ACC-RI: ROCK ISLAND (INACTIVE)
# 29302     ACC    ACC CTRS       ACC-RI             ACC-RI: ROCK ISLAND
# 29314     ACC    ACC CTRS       ACC-RI  ACC-RI: ROCK ISLAND (INACTIVE)
# 29315     ACC    ACC CTRS       ACC-RI             ACC-RI: ROCK ISLAND
#
#       Office Id  ...                   Bundling Contract Expiration Flag  \
# 25880    W52P1J  ...  NOT A BUNDLED REQUIREMENT              ONE OR LESS
# 25895    W519TC  ...                NOT BUNDLED              ONE OR LESS
# 25896    W519TC  ...                NOT BUNDLED              ONE OR LESS
# 25910    W52P1J  ...  NOT A BUNDLED REQUIREMENT              ONE OR LESS
# 25922    W519TC  ...                NOT BUNDLED              ONE OR LESS
# ...         ...  ...                        ...                      ...
# 29291    W52P1J  ...  NOT A BUNDLED REQUIREMENT              ONE OR LESS
# 29296    W52P1J  ...                NOT BUNDLED              ONE OR LESS
# 29302    W519TC  ...                NOT BUNDLED              ONE OR LESS
# 29314    W52P1J  ...                NOT BUNDLED              ONE OR LESS
# 29315    W519TC  ...                NOT BUNDLED              ONE OR LESS
#
#        Expiration Months Remaining  Awarding PCO (CWS)  \
# 25880  2017-04-14            -95.0   SINNOTT, DANIEL S
# 25895  2019-09-29            -65.0      DORAN, JAMES W
# 25896  2022-12-13            -26.0     TUTOR, NATHAN S
# 25910  2019-09-26            -65.0   SINNOTT, DANIEL S
# 25922  2020-05-30            -57.0      WARD, KATHLEEN
# ...           ...              ...                 ...
# 29291  2019-09-30            -65.0   KRAMER, BRIDGET L
# 29296  2021-05-31            -45.0      PIERCE, RYAN C
# 29302  2023-12-27            -13.0      MARTINEZ, MARK
# 29314  2021-08-03            -43.0  GAINEY, DANIELLE M
# 29315  2022-04-21            -34.0        YOUNG, KATIE
#
#              Type Set Aside Description  \
# 25880                  8(A) SOLE SOURCE
# 25895                 NO SET ASIDE USED
# 25896                 NO SET ASIDE USED
# 25910                  8(A) SOLE SOURCE
# 25922  SMALL BUSINESS SET ASIDE - TOTAL
# ...                                 ...
# 29291  SMALL BUSINESS SET ASIDE - TOTAL
# 29296  SMALL BUSINESS SET ASIDE - TOTAL
# 29302  SMALL BUSINESS SET ASIDE - TOTAL
# 29314  SMALL BUSINESS SET ASIDE - TOTAL
# 29315                 NO SET ASIDE USED
#
#                                 Requirements Description  \
# 25880  ORACLE HARDWARE MAINTENANCE AND TECHNICAL SUPP...
# 25895  THE PURPOSE OF THIS MODIFICATION IS TO DEOBLIG...
# 25896  DE-OBLIGATE $0.001 FROM CLIN 0002 FROM AN ADMI...
# 25910                                    DE-OBLIGATE .02
# 25922           DE-OBLIGATE EXCESS FUNDS FROM CLIN 1001.
# ...                                                  ...
# 29291  DEMILITARIZATION AND DISPOSAL OF\nHEXACHLOROET...
# 29296  MODIFICATION 40 WILL BE DE-OBLIGATING FY20 FUN...
# 29302  DE-OBLIGATE FUNDS FROM OP1 AND OP2 CLINS, ALON...
# 29314                        TERMINATION FOR CONVENIENCE
# 29315  MODIFICATION P00003 TERMINATES FOR CONVENIENCE...
#
#                12C Reason for Modification Description  Contract Action Type  \
# 25880                              FUNDING ONLY ACTION          MODIFICATION
# 25895                      OTHER ADMINISTRATIVE ACTION          MODIFICATION
# 25896                      OTHER ADMINISTRATIVE ACTION          MODIFICATION
# 25910                              FUNDING ONLY ACTION          MODIFICATION
# 25922                              FUNDING ONLY ACTION          MODIFICATION
# ...                                                ...                   ...
# 29291      TERMINATE FOR DEFAULT (COMPLETE OR PARTIAL)          MODIFICATION
# 29296                              FUNDING ONLY ACTION          MODIFICATION
# 29302                                     CHANGE ORDER          MODIFICATION
# 29314  TERMINATE FOR CONVENIENCE (COMPLETE OR PARTIAL)          MODIFICATION
# 29315  TERMINATE FOR CONVENIENCE (COMPLETE OR PARTIAL)          MODIFICATION
#
#                 Instrument Type
# 25880  Call/Delivery/Task Order
# 25895  Call/Delivery/Task Order
# 25896  Call/Delivery/Task Order
# 25910                         P
# 25922  Call/Delivery/Task Order
# ...                         ...
# 29291                         C
# 29296  Call/Delivery/Task Order
# 29302  Call/Delivery/Task Order
# 29314  Call/Delivery/Task Order
# 29315  Call/Delivery/Task Order
#
# [1571 rows x 56 columns]

# %%
# Detect duplicate recrods in dataframe
duplicates = df[df.duplicated(subset=['Contract No', "NAICS"], keep=False)]
print("Duplicate Records:\n", duplicates)
# Out:
# Duplicate Records:
#           Contract No       Order No Modification No Award Date  Fiscal Year  \
# 0      W52P1J19D0085  W519TC24F0272              00 2024-06-28         2024
# 1      W52P1J19D0045  W52P1J19F0400          P00062 2023-05-25         2023
# 2      W52P1J19D0085  W519TC24F0083              00 2024-03-05         2024
# 3      W52P1J19D0075  W519TC23F0171              00 2023-03-24         2023
# 4      W519TC25D0003  W519TC25F0015              00 2024-11-06         2025
# ...              ...            ...             ...        ...          ...
# 29324  W52P1J07D0007           0007              BE 2024-06-14         2024
# 29325  W52P1J09G0001  W519TC23F0092          P00003 2024-09-04         2024
# 29326  W519TC24D0024  W519TC24F0284          P00001 2024-09-13         2024
# 29327  W52P1J19D0085  W52P1J21F0045          P00038 2024-09-27         2024
# 29328  W52P1J19D0075  W519TC23F0171          P00001 2023-05-31         2023
#
#       Command Sub Command Organization               Office Office Id  ...  \
# 0         ACC    ACC CTRS       ACC-RI  ACC-RI: ROCK ISLAND    W519TC  ...
# 1         ACC    ACC CTRS       ACC-RI  ACC-RI: ROCK ISLAND    W519TC  ...
# 2         ACC    ACC CTRS       ACC-RI  ACC-RI: ROCK ISLAND    W519TC  ...
# 3         ACC    ACC CTRS       ACC-RI  ACC-RI: ROCK ISLAND    W519TC  ...
# 4         ACC    ACC CTRS       ACC-RI  ACC-RI: ROCK ISLAND    W519TC  ...
# ...       ...         ...          ...                  ...       ...  ...
# 29324     ACC    ACC CTRS       ACC-RI  ACC-RI: ROCK ISLAND    W519TC  ...
# 29325     ACC    ACC CTRS       ACC-RI  ACC-RI: ROCK ISLAND    W519TC  ...
# 29326     ACC    ACC CTRS       ACC-RI  ACC-RI: ROCK ISLAND    W519TC  ...
# 29327     ACC    ACC CTRS       ACC-RI  ACC-RI: ROCK ISLAND    W519TC  ...
# 29328     ACC    ACC CTRS       ACC-RI  ACC-RI: ROCK ISLAND    W519TC  ...
#
#                         Bundling Contract Expiration Flag  Expiration  \
# 0                    NOT BUNDLED       TWO TO THREE YEARS  2026-05-31
# 1                    NOT BUNDLED              ONE OR LESS  2024-06-30
# 2                    NOT BUNDLED       TWO TO THREE YEARS  2027-10-20
# 3                    NOT BUNDLED         ONE TO TWO YEARS  2025-09-24
# 4                    NOT BUNDLED      THREE TO FOUR YEARS  2028-10-31
# ...                          ...                      ...         ...
# 29324  NOT A BUNDLED REQUIREMENT              ONE OR LESS  2022-06-12
# 29325                NOT BUNDLED              ONE OR LESS  2024-11-30
# 29326                NOT BUNDLED         ONE TO TWO YEARS  2026-07-14
# 29327                NOT BUNDLED      THREE TO FOUR YEARS  2027-09-30
# 29328                NOT BUNDLED         ONE TO TWO YEARS  2025-09-24
#
#       Months Remaining    Awarding PCO (CWS) Type Set Aside Description  \
# 0                 16.0  STYVAERT, BENJAMIN W          NO SET ASIDE USED
# 1                 -7.0    TALBOT, MICHELLE M          NO SET ASIDE USED
# 2                 33.0  STYVAERT, BENJAMIN W          NO SET ASIDE USED
# 3                  8.0      WHITCOMB, ANNA E          NO SET ASIDE USED
# 4                 46.0    GARNICA, BRANDON M          NO SET ASIDE USED
# ...                ...                   ...                        ...
# 29324            -32.0    MONTELLANO, VICTOR          NO SET ASIDE USED
# 29325             -2.0        BIXLER, BEAU J          NO SET ASIDE USED
# 29326             18.0        HITT, SHELLY A          NO SET ASIDE USED
# 29327             32.0  STYVAERT, BENJAMIN W          NO SET ASIDE USED
# 29328              8.0      WHITCOMB, ANNA E          NO SET ASIDE USED
#
#                                 Requirements Description  \
# 0                          AWARD FY24 PRODUCTION ORDERS.
# 1      THIS MODIFICATION EXERCISES OPTION YEAR 2 (OY2...
# 2           NGSW FACILITY CONSTRUCTION SOW AT LCAAP UCO.
# 3      155MM CAPACITY EXPANSION PROJECT FOR M795 AND ...
# 4      ESTABLISHMENT WITHIN THE CONTINENTAL UNITED ST...
# ...                                                  ...
# 29324            UCO DEFINITIZATION AND ULO DEOBLIGATION
# 29325  THE TASK ORDER IS FOR THE CONTRACTOR TO CONDUC...
# 29326  ADJUSTMENT TO FUNDING BASIS HARDWARE VS SERVIC...
# 29327  DEOBLIGATION OF FUNDS TO REFUND WITH CORRECT U...
# 29328  RESCOPE OF 65K EXPANDED CAPACITY TO 35K MONTHL...
#
#             12C Reason for Modification Description  Contract Action Type  \
# 0                                               NaN   TASK/DELIVERY ORDER
# 1                                EXERCISE AN OPTION          MODIFICATION
# 2                                               NaN   TASK/DELIVERY ORDER
# 3                                               NaN   TASK/DELIVERY ORDER
# 4                                               NaN   TASK/DELIVERY ORDER
# ...                                             ...                   ...
# 29324                       DEFINITIZE CHANGE ORDER          MODIFICATION
# 29325  SUPPLEMENTAL AGREEMENT FOR WORK WITHIN SCOPE          MODIFICATION
# 29326  SUPPLEMENTAL AGREEMENT FOR WORK WITHIN SCOPE          MODIFICATION
# 29327                                  CHANGE ORDER          MODIFICATION
# 29328                                  CHANGE ORDER          MODIFICATION
#
#                 Instrument Type
# 0      Call/Delivery/Task Order
# 1      Call/Delivery/Task Order
# 2      Call/Delivery/Task Order
# 3      Call/Delivery/Task Order
# 4      Call/Delivery/Task Order
# ...                         ...
# 29324  Call/Delivery/Task Order
# 29325  Call/Delivery/Task Order
# 29326  Call/Delivery/Task Order
# 29327  Call/Delivery/Task Order
# 29328  Call/Delivery/Task Order
#
# [27186 rows x 56 columns]

# %%
# Standardize text data
df['Contract No'] = df['Contract No'].str.upper()
print("Standardized Contract No:\n", df['Contract No'])
# Out:
# Standardized Contract No:
#  0        W52P1J19D0085
# 1        W52P1J19D0045
# 2        W52P1J19D0085
# 3        W52P1J19D0075
# 4        W519TC25D0003
#              ...
# 29324    W52P1J07D0007
# 29325    W52P1J09G0001
# 29326    W519TC24D0024
# 29327    W52P1J19D0085
# 29328    W52P1J19D0075
# Name: Contract No, Length: 29329, dtype: object

# %%
# Convert 'NAICS' column to string type
df['NAICS'] = df['NAICS'].astype(str)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29329 entries, 0 to 29328
# Data columns (total 56 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Contract No                              29329 non-null  object
#  1   Order No                                 29329 non-null  object
#  2   Modification No                          29329 non-null  object
#  3   Award Date                               29329 non-null  datetime64[ns]
#  4   Fiscal Year                              29329 non-null  int64
#  5   Command                                  29329 non-null  object
#  6   Sub Command                              29329 non-null  object
#  7   Organization                             29329 non-null  object
#  8   Office                                   29329 non-null  object
#  9   Office Id                                29329 non-null  object
#  10  Army Hierarchy                           29024 non-null  object
#  11  PEO/Command                              29024 non-null  object
#  12  PM/Directorate                           29024 non-null  object
#  13  VCE-PCF Project/Program Title            3950 non-null   object
#  14  Funding Office Id                        29329 non-null  object
#  15  Funding Office Name                      29329 non-null  object
#  16  Awardee                                  29328 non-null  object
#  17  Entity Unique Id                         29326 non-null  object
#  18  Small Business Eligible Actions          29329 non-null  int64
#  19  Small Business Eligible Dollars          29329 non-null  float64
#  20  Size Status                              29329 non-null  object
#  21  SB Dollars                               29329 non-null  float64
#  22  Small Business  %                        29329 non-null  object
#  23  SDB Concern Actions                      29329 non-null  int64
#  24  SDB Concern Dollars                      29329 non-null  float64
#  25  SDB Concern %                            29329 non-null  object
#  26  Service Disabled Veterans Actions        29329 non-null  int64
#  27  Service Disabled Veterans Dollars        29329 non-null  float64
#  28  SVC Disabled Veteran %                   29329 non-null  object
#  29  Women Owned Actions                      29329 non-null  int64
#  30  Women Owned Dollars                      29329 non-null  float64
#  31  Women Owned %                            29329 non-null  object
#  32  HUB Zone Actions                         29329 non-null  int64
#  33  HUB Zone Dollars                         29329 non-null  float64
#  34  HUB Zone %                               29329 non-null  object
#  35  OMB Level 1                              29329 non-null  object
#  36  OMB Level 2                              29329 non-null  object
#  37  PSC                                      29329 non-null  object
#  38  PSC Description                          29312 non-null  object
#  39  NAICS                                    29329 non-null  object
#  40  NAICS Description                        29325 non-null  object
#  41  Congressional District - Vendor          28239 non-null  float64
#  42  Congressional District - POP             24150 non-null  float64
#  43  Subcontracting Plan Description          24933 non-null  object
#  44  National Interest Description            23149 non-null  object
#  45  SBIR/STTR Type                           53 non-null     object
#  46  Bundling                                 29185 non-null  object
#  47  Contract Expiration Flag                 29329 non-null  object
#  48  Expiration                               25298 non-null  object
#  49  Months Remaining                         25298 non-null  float64
#  50  Awarding PCO (CWS)                       28733 non-null  object
#  51  Type Set Aside Description               29329 non-null  object
#  52  Requirements Description                 29329 non-null  object
#  53  12C Reason for Modification Description  21632 non-null  object
#  54  Contract Action Type                     29329 non-null  object
#  55  Instrument Type                          29329 non-null  object
# dtypes: datetime64[ns](1), float64(9), int64(6), object(40)
# memory usage: 12.5+ MB

# %%
# Validate data ranges to ensure they are within expected ranges
invalid_naics = df[~df['NAICS'].str.match(r'^\d{6}$')] # Check if NAICS codes are 6 digits
print("Invalid NAICS Codes:\n", invalid_naics)
# Out:
# Invalid NAICS Codes:
#           Contract No       Order No Modification No Award Date  Fiscal Year  \
# 0      W52P1J19D0085  W519TC24F0272              00 2024-06-28         2024
# 1      W52P1J19D0045  W52P1J19F0400          P00062 2023-05-25         2023
# 2      W52P1J19D0085  W519TC24F0083              00 2024-03-05         2024
# 3      W52P1J19D0075  W519TC23F0171              00 2023-03-24         2023
# 4      W519TC25D0003  W519TC25F0015              00 2024-11-06         2025
# ...              ...            ...             ...        ...          ...
# 29324  W52P1J07D0007           0007              BE 2024-06-14         2024
# 29325  W52P1J09G0001  W519TC23F0092          P00003 2024-09-04         2024
# 29326  W519TC24D0024  W519TC24F0284          P00001 2024-09-13         2024
# 29327  W52P1J19D0085  W52P1J21F0045          P00038 2024-09-27         2024
# 29328  W52P1J19D0075  W519TC23F0171          P00001 2023-05-31         2023
#
#       Command Sub Command Organization               Office Office Id  ...  \
# 0         ACC    ACC CTRS       ACC-RI  ACC-RI: ROCK ISLAND    W519TC  ...
# 1         ACC    ACC CTRS       ACC-RI  ACC-RI: ROCK ISLAND    W519TC  ...
# 2         ACC    ACC CTRS       ACC-RI  ACC-RI: ROCK ISLAND    W519TC  ...
# 3         ACC    ACC CTRS       ACC-RI  ACC-RI: ROCK ISLAND    W519TC  ...
# 4         ACC    ACC CTRS       ACC-RI  ACC-RI: ROCK ISLAND    W519TC  ...
# ...       ...         ...          ...                  ...       ...  ...
# 29324     ACC    ACC CTRS       ACC-RI  ACC-RI: ROCK ISLAND    W519TC  ...
# 29325     ACC    ACC CTRS       ACC-RI  ACC-RI: ROCK ISLAND    W519TC  ...
# 29326     ACC    ACC CTRS       ACC-RI  ACC-RI: ROCK ISLAND    W519TC  ...
# 29327     ACC    ACC CTRS       ACC-RI  ACC-RI: ROCK ISLAND    W519TC  ...
# 29328     ACC    ACC CTRS       ACC-RI  ACC-RI: ROCK ISLAND    W519TC  ...
#
#                         Bundling Contract Expiration Flag  Expiration  \
# 0                    NOT BUNDLED       TWO TO THREE YEARS  2026-05-31
# 1                    NOT BUNDLED              ONE OR LESS  2024-06-30
# 2                    NOT BUNDLED       TWO TO THREE YEARS  2027-10-20
# 3                    NOT BUNDLED         ONE TO TWO YEARS  2025-09-24
# 4                    NOT BUNDLED      THREE TO FOUR YEARS  2028-10-31
# ...                          ...                      ...         ...
# 29324  NOT A BUNDLED REQUIREMENT              ONE OR LESS  2022-06-12
# 29325                NOT BUNDLED              ONE OR LESS  2024-11-30
# 29326                NOT BUNDLED         ONE TO TWO YEARS  2026-07-14
# 29327                NOT BUNDLED      THREE TO FOUR YEARS  2027-09-30
# 29328                NOT BUNDLED         ONE TO TWO YEARS  2025-09-24
#
#       Months Remaining    Awarding PCO (CWS) Type Set Aside Description  \
# 0                 16.0  STYVAERT, BENJAMIN W          NO SET ASIDE USED
# 1                 -7.0    TALBOT, MICHELLE M          NO SET ASIDE USED
# 2                 33.0  STYVAERT, BENJAMIN W          NO SET ASIDE USED
# 3                  8.0      WHITCOMB, ANNA E          NO SET ASIDE USED
# 4                 46.0    GARNICA, BRANDON M          NO SET ASIDE USED
# ...                ...                   ...                        ...
# 29324            -32.0    MONTELLANO, VICTOR          NO SET ASIDE USED
# 29325             -2.0        BIXLER, BEAU J          NO SET ASIDE USED
# 29326             18.0        HITT, SHELLY A          NO SET ASIDE USED
# 29327             32.0  STYVAERT, BENJAMIN W          NO SET ASIDE USED
# 29328              8.0      WHITCOMB, ANNA E          NO SET ASIDE USED
#
#                                 Requirements Description  \
# 0                          AWARD FY24 PRODUCTION ORDERS.
# 1      THIS MODIFICATION EXERCISES OPTION YEAR 2 (OY2...
# 2           NGSW FACILITY CONSTRUCTION SOW AT LCAAP UCO.
# 3      155MM CAPACITY EXPANSION PROJECT FOR M795 AND ...
# 4      ESTABLISHMENT WITHIN THE CONTINENTAL UNITED ST...
# ...                                                  ...
# 29324            UCO DEFINITIZATION AND ULO DEOBLIGATION
# 29325  THE TASK ORDER IS FOR THE CONTRACTOR TO CONDUC...
# 29326  ADJUSTMENT TO FUNDING BASIS HARDWARE VS SERVIC...
# 29327  DEOBLIGATION OF FUNDS TO REFUND WITH CORRECT U...
# 29328  RESCOPE OF 65K EXPANDED CAPACITY TO 35K MONTHL...
#
#             12C Reason for Modification Description  Contract Action Type  \
# 0                                               NaN   TASK/DELIVERY ORDER
# 1                                EXERCISE AN OPTION          MODIFICATION
# 2                                               NaN   TASK/DELIVERY ORDER
# 3                                               NaN   TASK/DELIVERY ORDER
# 4                                               NaN   TASK/DELIVERY ORDER
# ...                                             ...                   ...
# 29324                       DEFINITIZE CHANGE ORDER          MODIFICATION
# 29325  SUPPLEMENTAL AGREEMENT FOR WORK WITHIN SCOPE          MODIFICATION
# 29326  SUPPLEMENTAL AGREEMENT FOR WORK WITHIN SCOPE          MODIFICATION
# 29327                                  CHANGE ORDER          MODIFICATION
# 29328                                  CHANGE ORDER          MODIFICATION
#
#                 Instrument Type
# 0      Call/Delivery/Task Order
# 1      Call/Delivery/Task Order
# 2      Call/Delivery/Task Order
# 3      Call/Delivery/Task Order
# 4      Call/Delivery/Task Order
# ...                         ...
# 29324  Call/Delivery/Task Order
# 29325  Call/Delivery/Task Order
# 29326  Call/Delivery/Task Order
# 29327  Call/Delivery/Task Order
# 29328  Call/Delivery/Task Order
#
# [29329 rows x 56 columns]

# %%
# Ensure NAICS values are only six digits and remove any values after six digits
df['NAICS'] = df['NAICS'].str[:6]
print("Invalid NAICS Codes Corrected:\n", df['NAICS'])
# Out:
# Invalid NAICS Codes Corrected:
#  0        332992
# 1        561210
# 2        332992
# 3        561210
# 4        325920
#           ...
# 29324    561210
# 29325    561210
# 29326    517410
# 29327    332992
# 29328    561210
# Name: NAICS, Length: 29329, dtype: object

# %%
invalid_naics = df[~df['NAICS'].str.match(r'^\d{6}$')] # Check if NAICS codes are 6 digits
print("Invalid NAICS Codes:\n", invalid_naics)
# Out:
# Invalid NAICS Codes:
#           Contract No Order No Modification No Award Date  Fiscal Year Command  \
# 21285  DAAA0999D0016     0012              47 2022-02-22         2022     ACC
# 21286  DAAA0999D0016     0012              48 2022-08-22         2022     ACC
# 21287  DAAA0999D0016     0012              49 2022-09-01         2022     ACC
# 27300  DAAA0997C0098     0000          P00398 2022-09-19         2022     ACC
#
#       Sub Command Organization                          Office Office Id  ...  \
# 21285    ACC CTRS       ACC-RI  ACC-RI: ROCK ISLAND (INACTIVE)    W52P1J  ...
# 21286    ACC CTRS       ACC-RI  ACC-RI: ROCK ISLAND (INACTIVE)    W52P1J  ...
# 21287    ACC CTRS       ACC-RI  ACC-RI: ROCK ISLAND (INACTIVE)    W52P1J  ...
# 27300    ACC CTRS       ACC-RI  ACC-RI: ROCK ISLAND (INACTIVE)    W52P1J  ...
#
#                         Bundling Contract Expiration Flag  Expiration  \
# 21285  NOT A BUNDLED REQUIREMENT              ONE OR LESS  2011-09-30
# 21286  NOT A BUNDLED REQUIREMENT              ONE OR LESS  2011-09-30
# 21287  NOT A BUNDLED REQUIREMENT              ONE OR LESS  2011-09-30
# 27300                        NaN              ONE OR LESS  2018-09-23
#
#       Months Remaining  Awarding PCO (CWS) Type Set Aside Description  \
# 21285           -162.0  MCCLEARY, AMANDA S          NO SET ASIDE USED
# 21286           -162.0  MCCLEARY, AMANDA S          NO SET ASIDE USED
# 21287           -162.0  MCCLEARY, AMANDA S          NO SET ASIDE USED
# 27300            -77.0                 NaN          NO SET ASIDE USED
#
#                                 Requirements Description  \
# 21285  ADMINISTRATIVE MODIFICATION TO CORRECT CLIN 12...
# 21286  ADMINISTRATIVELY REDUCE THE AMOUNT OF DE-OBLIG...
# 21287  ADMINISTRATIVELY RESCINDING MOD 47 AND DOCUMEN...
# 27300  SERVICE CONTRACT FOR THE LIFE CYCLE OF OPERATI...
#
#             12C Reason for Modification Description  Contract Action Type  \
# 21285                           FUNDING ONLY ACTION          MODIFICATION
# 21286  SUPPLEMENTAL AGREEMENT FOR WORK WITHIN SCOPE          MODIFICATION
# 21287  SUPPLEMENTAL AGREEMENT FOR WORK WITHIN SCOPE          MODIFICATION
# 27300                           FUNDING ONLY ACTION          MODIFICATION
#
#                 Instrument Type
# 21285  Call/Delivery/Task Order
# 21286  Call/Delivery/Task Order
# 21287  Call/Delivery/Task Order
# 27300                         C
#
# [4 rows x 56 columns]

# %%
# Count unique values in a column
unique_naics = df['NAICS'].nunique()

# Count unique NAICS in Fiscal Year 2024 where fiscal year is 10/1/2023 - 9/30/2024
fy_2024 = df[(df['Award Date'] >= '2023-10-01') & (df['Award Date'] <= '2024-09-30')]

# Count unique NAICS in Fiscal Year 2023
fy_2023 = df[(df['Award Date'] >= '2022-10-01') & (df['Award Date'] <= '2023-09-30')]
unique_fy23_naics = fy_2023['NAICS'].nunique()

# Count unique NAICS in Fiscal Year 2022
fy_2022 = df[(df['Award Date'] >= '2021-10-01') & (df['Award Date'] <= '2022-09-30')]
unique_fy22_naics = fy_2022['NAICS'].nunique()

unique_fy24_naics = fy_2024['NAICS'].nunique()
print("Unique NAICS Codes:", unique_naics)
print("Unique NAICS Codes in FY 2024:", unique_fy24_naics)
print("Unique NAICS Codes in FY 2023:", unique_fy23_naics)
print("Unique NAICS Codes in FY 2022:", unique_fy22_naics)
# Out:
# Unique NAICS Codes: 441
# Unique NAICS Codes in FY 2024: 296
# Unique NAICS Codes in FY 2023: 328
# Unique NAICS Codes in FY 2022: 293

# %%
# Identify how many instances each NAICS code had where it was labeled as SB in the "Size Status" column
sb_naics = df[df['Size Status'] == 'SB']
sb_naics_count = sb_naics['NAICS'].value_counts()
# only dispaly NAICS code with a count greater than 2
sb_naics_count = sb_naics_count[sb_naics_count > 2]
print("SB NAICS Codes:\n", sb_naics_count)
# print("SB NAICS Codes:\n", sb_naics_count)
# Out:
# SB NAICS Codes:
#  NAICS
# 561210    3269
# 541519    1099
# 334111     740
# 332993     486
# 541512     471
#           ...
# 332721       3
# 336310       3
# 333613       3
# 212322       3
# 541850       3
# Name: count, Length: 308, dtype: int64
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
#Check for inconsistent formatting across NAICS codes to ensure no more than 6 digits
inconsistent_naics = df[~df['NAICS'].str.match(r'^\d{6}$')]
print("Inconsistent NAICS Codes:\n", inconsistent_naics)
# Out:
# Inconsistent NAICS Codes:
#           Contract No Order No Modification No Award Date  Fiscal Year Command  \
# 21285  DAAA0999D0016     0012              47 2022-02-22         2022     ACC
# 21286  DAAA0999D0016     0012              48 2022-08-22         2022     ACC
# 21287  DAAA0999D0016     0012              49 2022-09-01         2022     ACC
# 27300  DAAA0997C0098     0000          P00398 2022-09-19         2022     ACC
#
#       Sub Command Organization                          Office Office Id  ...  \
# 21285    ACC CTRS       ACC-RI  ACC-RI: ROCK ISLAND (INACTIVE)    W52P1J  ...
# 21286    ACC CTRS       ACC-RI  ACC-RI: ROCK ISLAND (INACTIVE)    W52P1J  ...
# 21287    ACC CTRS       ACC-RI  ACC-RI: ROCK ISLAND (INACTIVE)    W52P1J  ...
# 27300    ACC CTRS       ACC-RI  ACC-RI: ROCK ISLAND (INACTIVE)    W52P1J  ...
#
#                         Bundling Contract Expiration Flag  Expiration  \
# 21285  NOT A BUNDLED REQUIREMENT              ONE OR LESS  2011-09-30
# 21286  NOT A BUNDLED REQUIREMENT              ONE OR LESS  2011-09-30
# 21287  NOT A BUNDLED REQUIREMENT              ONE OR LESS  2011-09-30
# 27300                        NaN              ONE OR LESS  2018-09-23
#
#       Months Remaining  Awarding PCO (CWS) Type Set Aside Description  \
# 21285           -162.0  MCCLEARY, AMANDA S          NO SET ASIDE USED
# 21286           -162.0  MCCLEARY, AMANDA S          NO SET ASIDE USED
# 21287           -162.0  MCCLEARY, AMANDA S          NO SET ASIDE USED
# 27300            -77.0                 NaN          NO SET ASIDE USED
#
#                                 Requirements Description  \
# 21285  ADMINISTRATIVE MODIFICATION TO CORRECT CLIN 12...
# 21286  ADMINISTRATIVELY REDUCE THE AMOUNT OF DE-OBLIG...
# 21287  ADMINISTRATIVELY RESCINDING MOD 47 AND DOCUMEN...
# 27300  SERVICE CONTRACT FOR THE LIFE CYCLE OF OPERATI...
#
#             12C Reason for Modification Description  Contract Action Type  \
# 21285                           FUNDING ONLY ACTION          MODIFICATION
# 21286  SUPPLEMENTAL AGREEMENT FOR WORK WITHIN SCOPE          MODIFICATION
# 21287  SUPPLEMENTAL AGREEMENT FOR WORK WITHIN SCOPE          MODIFICATION
# 27300                           FUNDING ONLY ACTION          MODIFICATION
#
#                 Instrument Type
# 21285  Call/Delivery/Task Order
# 21286  Call/Delivery/Task Order
# 21287  Call/Delivery/Task Order
# 27300                         C
#
# [4 rows x 56 columns]

# %%
# convert contract number dtype to str dtype
df['Contract No'] = df['Contract No'].astype(str)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29329 entries, 0 to 29328
# Data columns (total 56 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Contract No                              29329 non-null  object
#  1   Order No                                 29329 non-null  object
#  2   Modification No                          29329 non-null  object
#  3   Award Date                               29329 non-null  datetime64[ns]
#  4   Fiscal Year                              29329 non-null  int64
#  5   Command                                  29329 non-null  object
#  6   Sub Command                              29329 non-null  object
#  7   Organization                             29329 non-null  object
#  8   Office                                   29329 non-null  object
#  9   Office Id                                29329 non-null  object
#  10  Army Hierarchy                           29024 non-null  object
#  11  PEO/Command                              29024 non-null  object
#  12  PM/Directorate                           29024 non-null  object
#  13  VCE-PCF Project/Program Title            3950 non-null   object
#  14  Funding Office Id                        29329 non-null  object
#  15  Funding Office Name                      29329 non-null  object
#  16  Awardee                                  29328 non-null  object
#  17  Entity Unique Id                         29326 non-null  object
#  18  Small Business Eligible Actions          29329 non-null  int64
#  19  Small Business Eligible Dollars          29329 non-null  float64
#  20  Size Status                              29329 non-null  object
#  21  SB Dollars                               29329 non-null  float64
#  22  Small Business  %                        29329 non-null  object
#  23  SDB Concern Actions                      29329 non-null  int64
#  24  SDB Concern Dollars                      29329 non-null  float64
#  25  SDB Concern %                            29329 non-null  object
#  26  Service Disabled Veterans Actions        29329 non-null  int64
#  27  Service Disabled Veterans Dollars        29329 non-null  float64
#  28  SVC Disabled Veteran %                   29329 non-null  object
#  29  Women Owned Actions                      29329 non-null  int64
#  30  Women Owned Dollars                      29329 non-null  float64
#  31  Women Owned %                            29329 non-null  object
#  32  HUB Zone Actions                         29329 non-null  int64
#  33  HUB Zone Dollars                         29329 non-null  float64
#  34  HUB Zone %                               29329 non-null  object
#  35  OMB Level 1                              29329 non-null  object
#  36  OMB Level 2                              29329 non-null  object
#  37  PSC                                      29329 non-null  object
#  38  PSC Description                          29312 non-null  object
#  39  NAICS                                    29329 non-null  object
#  40  NAICS Description                        29325 non-null  object
#  41  Congressional District - Vendor          28239 non-null  float64
#  42  Congressional District - POP             24150 non-null  float64
#  43  Subcontracting Plan Description          24933 non-null  object
#  44  National Interest Description            23149 non-null  object
#  45  SBIR/STTR Type                           53 non-null     object
#  46  Bundling                                 29185 non-null  object
#  47  Contract Expiration Flag                 29329 non-null  object
#  48  Expiration                               25298 non-null  object
#  49  Months Remaining                         25298 non-null  float64
#  50  Awarding PCO (CWS)                       28733 non-null  object
#  51  Type Set Aside Description               29329 non-null  object
#  52  Requirements Description                 29329 non-null  object
#  53  12C Reason for Modification Description  21632 non-null  object
#  54  Contract Action Type                     29329 non-null  object
#  55  Instrument Type                          29329 non-null  object
# dtypes: datetime64[ns](1), float64(9), int64(6), object(40)
# memory usage: 12.5+ MB

# %%
inconsistent_contract_no = df[~df['Contract No'].str.match(r'^\d{13}$')] # Check if Contract No. codes are 13 digits
print("Inconsistent Contract Numbers:\n", inconsistent_contract_no)
# Out:
# Inconsistent Contract Numbers:
#           Contract No       Order No Modification No Award Date  Fiscal Year  \
# 0      W52P1J19D0085  W519TC24F0272              00 2024-06-28         2024
# 1      W52P1J19D0045  W52P1J19F0400          P00062 2023-05-25         2023
# 2      W52P1J19D0085  W519TC24F0083              00 2024-03-05         2024
# 3      W52P1J19D0075  W519TC23F0171              00 2023-03-24         2023
# 4      W519TC25D0003  W519TC25F0015              00 2024-11-06         2025
# ...              ...            ...             ...        ...          ...
# 29324  W52P1J07D0007           0007              BE 2024-06-14         2024
# 29325  W52P1J09G0001  W519TC23F0092          P00003 2024-09-04         2024
# 29326  W519TC24D0024  W519TC24F0284          P00001 2024-09-13         2024
# 29327  W52P1J19D0085  W52P1J21F0045          P00038 2024-09-27         2024
# 29328  W52P1J19D0075  W519TC23F0171          P00001 2023-05-31         2023
#
#       Command Sub Command Organization               Office Office Id  ...  \
# 0         ACC    ACC CTRS       ACC-RI  ACC-RI: ROCK ISLAND    W519TC  ...
# 1         ACC    ACC CTRS       ACC-RI  ACC-RI: ROCK ISLAND    W519TC  ...
# 2         ACC    ACC CTRS       ACC-RI  ACC-RI: ROCK ISLAND    W519TC  ...
# 3         ACC    ACC CTRS       ACC-RI  ACC-RI: ROCK ISLAND    W519TC  ...
# 4         ACC    ACC CTRS       ACC-RI  ACC-RI: ROCK ISLAND    W519TC  ...
# ...       ...         ...          ...                  ...       ...  ...
# 29324     ACC    ACC CTRS       ACC-RI  ACC-RI: ROCK ISLAND    W519TC  ...
# 29325     ACC    ACC CTRS       ACC-RI  ACC-RI: ROCK ISLAND    W519TC  ...
# 29326     ACC    ACC CTRS       ACC-RI  ACC-RI: ROCK ISLAND    W519TC  ...
# 29327     ACC    ACC CTRS       ACC-RI  ACC-RI: ROCK ISLAND    W519TC  ...
# 29328     ACC    ACC CTRS       ACC-RI  ACC-RI: ROCK ISLAND    W519TC  ...
#
#                         Bundling Contract Expiration Flag  Expiration  \
# 0                    NOT BUNDLED       TWO TO THREE YEARS  2026-05-31
# 1                    NOT BUNDLED              ONE OR LESS  2024-06-30
# 2                    NOT BUNDLED       TWO TO THREE YEARS  2027-10-20
# 3                    NOT BUNDLED         ONE TO TWO YEARS  2025-09-24
# 4                    NOT BUNDLED      THREE TO FOUR YEARS  2028-10-31
# ...                          ...                      ...         ...
# 29324  NOT A BUNDLED REQUIREMENT              ONE OR LESS  2022-06-12
# 29325                NOT BUNDLED              ONE OR LESS  2024-11-30
# 29326                NOT BUNDLED         ONE TO TWO YEARS  2026-07-14
# 29327                NOT BUNDLED      THREE TO FOUR YEARS  2027-09-30
# 29328                NOT BUNDLED         ONE TO TWO YEARS  2025-09-24
#
#       Months Remaining    Awarding PCO (CWS) Type Set Aside Description  \
# 0                 16.0  STYVAERT, BENJAMIN W          NO SET ASIDE USED
# 1                 -7.0    TALBOT, MICHELLE M          NO SET ASIDE USED
# 2                 33.0  STYVAERT, BENJAMIN W          NO SET ASIDE USED
# 3                  8.0      WHITCOMB, ANNA E          NO SET ASIDE USED
# 4                 46.0    GARNICA, BRANDON M          NO SET ASIDE USED
# ...                ...                   ...                        ...
# 29324            -32.0    MONTELLANO, VICTOR          NO SET ASIDE USED
# 29325             -2.0        BIXLER, BEAU J          NO SET ASIDE USED
# 29326             18.0        HITT, SHELLY A          NO SET ASIDE USED
# 29327             32.0  STYVAERT, BENJAMIN W          NO SET ASIDE USED
# 29328              8.0      WHITCOMB, ANNA E          NO SET ASIDE USED
#
#                                 Requirements Description  \
# 0                          AWARD FY24 PRODUCTION ORDERS.
# 1      THIS MODIFICATION EXERCISES OPTION YEAR 2 (OY2...
# 2           NGSW FACILITY CONSTRUCTION SOW AT LCAAP UCO.
# 3      155MM CAPACITY EXPANSION PROJECT FOR M795 AND ...
# 4      ESTABLISHMENT WITHIN THE CONTINENTAL UNITED ST...
# ...                                                  ...
# 29324            UCO DEFINITIZATION AND ULO DEOBLIGATION
# 29325  THE TASK ORDER IS FOR THE CONTRACTOR TO CONDUC...
# 29326  ADJUSTMENT TO FUNDING BASIS HARDWARE VS SERVIC...
# 29327  DEOBLIGATION OF FUNDS TO REFUND WITH CORRECT U...
# 29328  RESCOPE OF 65K EXPANDED CAPACITY TO 35K MONTHL...
#
#             12C Reason for Modification Description  Contract Action Type  \
# 0                                               NaN   TASK/DELIVERY ORDER
# 1                                EXERCISE AN OPTION          MODIFICATION
# 2                                               NaN   TASK/DELIVERY ORDER
# 3                                               NaN   TASK/DELIVERY ORDER
# 4                                               NaN   TASK/DELIVERY ORDER
# ...                                             ...                   ...
# 29324                       DEFINITIZE CHANGE ORDER          MODIFICATION
# 29325  SUPPLEMENTAL AGREEMENT FOR WORK WITHIN SCOPE          MODIFICATION
# 29326  SUPPLEMENTAL AGREEMENT FOR WORK WITHIN SCOPE          MODIFICATION
# 29327                                  CHANGE ORDER          MODIFICATION
# 29328                                  CHANGE ORDER          MODIFICATION
#
#                 Instrument Type
# 0      Call/Delivery/Task Order
# 1      Call/Delivery/Task Order
# 2      Call/Delivery/Task Order
# 3      Call/Delivery/Task Order
# 4      Call/Delivery/Task Order
# ...                         ...
# 29324  Call/Delivery/Task Order
# 29325  Call/Delivery/Task Order
# 29326  Call/Delivery/Task Order
# 29327  Call/Delivery/Task Order
# 29328  Call/Delivery/Task Order
#
# [29329 rows x 56 columns]

# %%
# Identify rows with multiple issues
issues = df.isnull().any(axis=1) | (df['SB Dollars'] < 0) | (~df['NAICS'].str.match(r'^\d{6}$')) | (~df['Contract No'].str.match(r'^\d{13}$'))
print("Rows with Issues:\n", df[issues])
# Out:
# Rows with Issues:
#           Contract No       Order No Modification No Award Date  Fiscal Year  \
# 0      W52P1J19D0085  W519TC24F0272              00 2024-06-28         2024
# 1      W52P1J19D0045  W52P1J19F0400          P00062 2023-05-25         2023
# 2      W52P1J19D0085  W519TC24F0083              00 2024-03-05         2024
# 3      W52P1J19D0075  W519TC23F0171              00 2023-03-24         2023
# 4      W519TC25D0003  W519TC25F0015              00 2024-11-06         2025
# ...              ...            ...             ...        ...          ...
# 29324  W52P1J07D0007           0007              BE 2024-06-14         2024
# 29325  W52P1J09G0001  W519TC23F0092          P00003 2024-09-04         2024
# 29326  W519TC24D0024  W519TC24F0284          P00001 2024-09-13         2024
# 29327  W52P1J19D0085  W52P1J21F0045          P00038 2024-09-27         2024
# 29328  W52P1J19D0075  W519TC23F0171          P00001 2023-05-31         2023
#
#       Command Sub Command Organization               Office Office Id  ...  \
# 0         ACC    ACC CTRS       ACC-RI  ACC-RI: ROCK ISLAND    W519TC  ...
# 1         ACC    ACC CTRS       ACC-RI  ACC-RI: ROCK ISLAND    W519TC  ...
# 2         ACC    ACC CTRS       ACC-RI  ACC-RI: ROCK ISLAND    W519TC  ...
# 3         ACC    ACC CTRS       ACC-RI  ACC-RI: ROCK ISLAND    W519TC  ...
# 4         ACC    ACC CTRS       ACC-RI  ACC-RI: ROCK ISLAND    W519TC  ...
# ...       ...         ...          ...                  ...       ...  ...
# 29324     ACC    ACC CTRS       ACC-RI  ACC-RI: ROCK ISLAND    W519TC  ...
# 29325     ACC    ACC CTRS       ACC-RI  ACC-RI: ROCK ISLAND    W519TC  ...
# 29326     ACC    ACC CTRS       ACC-RI  ACC-RI: ROCK ISLAND    W519TC  ...
# 29327     ACC    ACC CTRS       ACC-RI  ACC-RI: ROCK ISLAND    W519TC  ...
# 29328     ACC    ACC CTRS       ACC-RI  ACC-RI: ROCK ISLAND    W519TC  ...
#
#                         Bundling Contract Expiration Flag  Expiration  \
# 0                    NOT BUNDLED       TWO TO THREE YEARS  2026-05-31
# 1                    NOT BUNDLED              ONE OR LESS  2024-06-30
# 2                    NOT BUNDLED       TWO TO THREE YEARS  2027-10-20
# 3                    NOT BUNDLED         ONE TO TWO YEARS  2025-09-24
# 4                    NOT BUNDLED      THREE TO FOUR YEARS  2028-10-31
# ...                          ...                      ...         ...
# 29324  NOT A BUNDLED REQUIREMENT              ONE OR LESS  2022-06-12
# 29325                NOT BUNDLED              ONE OR LESS  2024-11-30
# 29326                NOT BUNDLED         ONE TO TWO YEARS  2026-07-14
# 29327                NOT BUNDLED      THREE TO FOUR YEARS  2027-09-30
# 29328                NOT BUNDLED         ONE TO TWO YEARS  2025-09-24
#
#       Months Remaining    Awarding PCO (CWS) Type Set Aside Description  \
# 0                 16.0  STYVAERT, BENJAMIN W          NO SET ASIDE USED
# 1                 -7.0    TALBOT, MICHELLE M          NO SET ASIDE USED
# 2                 33.0  STYVAERT, BENJAMIN W          NO SET ASIDE USED
# 3                  8.0      WHITCOMB, ANNA E          NO SET ASIDE USED
# 4                 46.0    GARNICA, BRANDON M          NO SET ASIDE USED
# ...                ...                   ...                        ...
# 29324            -32.0    MONTELLANO, VICTOR          NO SET ASIDE USED
# 29325             -2.0        BIXLER, BEAU J          NO SET ASIDE USED
# 29326             18.0        HITT, SHELLY A          NO SET ASIDE USED
# 29327             32.0  STYVAERT, BENJAMIN W          NO SET ASIDE USED
# 29328              8.0      WHITCOMB, ANNA E          NO SET ASIDE USED
#
#                                 Requirements Description  \
# 0                          AWARD FY24 PRODUCTION ORDERS.
# 1      THIS MODIFICATION EXERCISES OPTION YEAR 2 (OY2...
# 2           NGSW FACILITY CONSTRUCTION SOW AT LCAAP UCO.
# 3      155MM CAPACITY EXPANSION PROJECT FOR M795 AND ...
# 4      ESTABLISHMENT WITHIN THE CONTINENTAL UNITED ST...
# ...                                                  ...
# 29324            UCO DEFINITIZATION AND ULO DEOBLIGATION
# 29325  THE TASK ORDER IS FOR THE CONTRACTOR TO CONDUC...
# 29326  ADJUSTMENT TO FUNDING BASIS HARDWARE VS SERVIC...
# 29327  DEOBLIGATION OF FUNDS TO REFUND WITH CORRECT U...
# 29328  RESCOPE OF 65K EXPANDED CAPACITY TO 35K MONTHL...
#
#             12C Reason for Modification Description  Contract Action Type  \
# 0                                               NaN   TASK/DELIVERY ORDER
# 1                                EXERCISE AN OPTION          MODIFICATION
# 2                                               NaN   TASK/DELIVERY ORDER
# 3                                               NaN   TASK/DELIVERY ORDER
# 4                                               NaN   TASK/DELIVERY ORDER
# ...                                             ...                   ...
# 29324                       DEFINITIZE CHANGE ORDER          MODIFICATION
# 29325  SUPPLEMENTAL AGREEMENT FOR WORK WITHIN SCOPE          MODIFICATION
# 29326  SUPPLEMENTAL AGREEMENT FOR WORK WITHIN SCOPE          MODIFICATION
# 29327                                  CHANGE ORDER          MODIFICATION
# 29328                                  CHANGE ORDER          MODIFICATION
#
#                 Instrument Type
# 0      Call/Delivery/Task Order
# 1      Call/Delivery/Task Order
# 2      Call/Delivery/Task Order
# 3      Call/Delivery/Task Order
# 4      Call/Delivery/Task Order
# ...                         ...
# 29324  Call/Delivery/Task Order
# 29325  Call/Delivery/Task Order
# 29326  Call/Delivery/Task Order
# 29327  Call/Delivery/Task Order
# 29328  Call/Delivery/Task Order
#
# [29329 rows x 56 columns]
